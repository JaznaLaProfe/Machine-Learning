# %% [markdown]
# # Uso de vectores y sistemas de ecuaciones
#
# **Autor:** Jazna Meza Hidalgo
#
# **Correo Electrónico:** ja.meza@profesor.duoc.cl
#
# **Fecha de Creación:** Marzo de 2025
#
# **Versión:** 1.0
#
# ---
#
# ## Descripción
#
# Los vectores son uno de los conceptos usados en el campo de Machine Learning.
#
# Este notebook explica la forma de trabajar con ellos en Python y su uso en la resolución de sistemas de ecuaciones.
#
# ---
#
# ## Requisitos de Software
#
# Este notebook fue desarrollado con Python 3.9. A continuación se listan las bibliotecas necesarias:
#
# - matplotlib (3.10.0)
# - numpy (1.26.4)
# - sympy (1.13.1)
#
# Para verificar la versión instalada ejecutar usando el siguiente comando, usando la librería de la cual quieres saber la versión:
#
# ```bash
# import numpy as np
# print(np.__version__)
# ````

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy

# %%
# Imprimir con notación matemática.
sympy.init_printing(use_latex='mathjax')

# %% [markdown]
# #Concepto de vector

# %%
# graficando vector en R^2 [2, 4]
def dibujar_figura():
  """Crea la figura de pyplot y los ejes."""
  fix, ax = plt.subplots()
  for spine in ["left", "bottom"]:
    ax.spines[spine].set_position("zero")

  return ax

# %%
def vector_plano(v : np.array, color):
    """Genera el grafico de los vectores en el plano"""
    ax.annotate(" ", xy=v, xytext=[0, 0], color=color,
                arrowprops=dict(facecolor=color,
                                shrink=0,
                                alpha=0.7,
                                width=0.5))
    ax.text(1.1 * v[0], 1.1 * v[1], str(v))

# %%
ax = dibujar_figura()
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.grid()
vector_plano([2, 4], "blue")

# Suma de dos vectores
# [3, 2] + [1, -2]

ax = dibujar_figura()
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.grid()

vecs = [[3, 2], [1, -2]]

for v in vecs:
  vector_plano(v, "blue")
# Realiza la suma
v = np.array([2, 4]) + np.array([2, -2])
vector_plano(v, "red")

# Multiplicacion de un vector con un escalar
# [1, 2] * 2
ax = dibujar_figura()
ax.set_xlim(-6, 6)
ax.set_ylim(-6, 6)
ax.grid()
# Define el vector
v = np.array([1, 2])

vector_plano(v, "blue")

# Multiplciacion por un escalar
v = v * 2
vector_plano(v, "red")

# %% [markdown]
# # Resolución de sistemas de ecuaciones

# %% [markdown]
# El sistema de ecuaciones que se resolverá es:
#
#
# \begin{cases}
# 2x + 3y + 5z = 52 \\
# 3x + 6y + 0z = 61 \\
# 8x + 3y + 6z = 75
# \end{cases}
#
# Sus matrices asociadas son:
#
# A =
# \begin{bmatrix}
# 2 & 3 & 5 \\
# 3 & 6 & 0 \\
# 8 & 3 & 6
# \end{bmatrix}
#
# b =
# \begin{bmatrix}
# 52 \\
# 61 \\
# 75
# \end{bmatrix}
# \]

# %%
"""
Resolución de sistemas de ecuaciones con python
"""
# También es posible resolver sistemas de ecuaciones haciendo uso de la libreria Sympy
# Primero se construye la matriz del sistema de ecuaciones
A = sympy.Matrix(( (2, 3, 5), (3, 6, 0), (8, 3, 6) ))
# Crea la matriz B
b = sympy.Matrix(3,1,(52,61,75))
# Resolver la ecuacion Ax = b
x = A.LUsolve(b)
# Mostrar la solucion
print(x)
# Comprobar la  la solución
print (A*x)
# Out:
# Matrix([[187/59], [1519/177], [235/59]])
# Matrix([[52], [61], [75]])

# %% [markdown]
# # Desafío
#
# Resuelva los siguientes sistemas de ecuaciones: muestre la solución y la comprobación de que es el resultado correcto

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# .
# .
# ![image.png](data:image/png;base64,...)
